# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")


#Load data set
df = pd.read_csv(r"D:\sir gen Ai\EDA\24th, 25th- Advanced EDA project\24th, 25th- Advanced EDA project\EDA- HEALTHCARE DOMAIN\heart.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# ##`1` stands for presence of heart disease. So, there are 165 patients suffering from heart disease.
#
# #- Similarly, `0` stands for absence of heart disease. So, there are 138 patients who do not have any heart disease.
#
# #- We can visualize this information below.

# %%
f, ax = plt.subplots(figsize=(8,6))
sns.countplot(x= 'target',data = df ,hue ='target')
plt.grid(False)
plt.title("Visualize The Frequency of Target Variable")
plt.show()

# %% [markdown]
# # Interpetation
#      * The above Graph says thet 165 aptients are suffering from hera deciese(target = 1)
#      * 138 patients are not suffering.(target = 0)

# %%
# Finding how many male patients and female patients are there in the data base 
# using groupby func with target variable and plotting with sex

df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %% [markdown]
# # summary
#    * By the above info out of 96 female(sex = 0) patients 72 are suffering from chest pain(target = 1)
#    and 24 are not(target = 0)
#    * out of 207 male(sex = 1) patients 114 are not suffering(target = 0) and 93 are suffering from pain(target = 1)

# %%
# plotting using above information with both variables sex and target
ax = plt.subplots(figsize=(8,6))
sns.countplot(x='sex',data = df, hue='target')
plt.title("Visualize The Frequency of Target Variable with sex")
plt.show()

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# considering age and chest pain as the two variables to plot
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df.groupby('cp')['age'].value_counts()
# Out:
# cp  age
# 0   57     11
#     58     10
#     59      7
#     60      7
#     62      7
#            ..
# 3   60      1
#     61      1
#     63      1
#     65      1
#     66      1
# Name: count, Length: 108, dtype: int64

# %%
ax= plt.subplots(figsize=(10,6))
sns.countplot(x='age',hue = 'cp',data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %% [markdown]
# #### Dataset description <a class="anchor" id="6.4"></a>
#
# - The dataset contains several columns which are as follows -
#
#   - age : age in years
#   - sex : (1 = male; 0 = female)
#   - cp : chest pain type
#   - trestbps : resting blood pressure (in mm Hg on admission to the hospital)
#   - chol : serum cholestoral in mg/dl
#   - fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#   - restecg : resting electrocardiographic results
#   - thalach : maximum heart rate achieved
#   - exang : exercise induced angina (1 = yes; 0 = no)
#   - oldpeak : ST depression induced by exercise relative to rest
#   - slope : the slope of the peak exercise ST segment
#   - ca : number of major vessels (0-3) colored by flourosopy
#   - thal : 3 = normal; 6 = fixed defect; 7 = reversable defect
#   - target : 1 or 0

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
# plotting graph with cp and target
ax = plt.subplots(figsize=(8,6))
sns.barplot(x = 'cp',y = 'target',data= df)
plt.show()

# %%
# plotting graph with cp and target
ax = plt.subplots(figsize=(8,6))
sns.countplot(x = 'cp',data= df,hue='target')
plt.show()

# %%
# catplot devides the "cp" data into subplots based on the unique values of the 'target' column
ax = sns.catplot(x="target", col="cp", data=df, kind="count", height=8, aspect=1,hue = 'target')

# %%
# catplot devides the 'age' data into subplots based on the unique values of the 'target' column
#plt.subplots(figsize=(8,6))
ax = sns.catplot(x="target", col="sex", data=df, kind="count",hue = 'target')

# %%
## analysis with target and fbs,exang(fasting blood sugar) and exercise induced angina
# counting the values of fbs and exang with target variable
ax =plt.subplots(figsize=(8,6))
sns.countplot(x='target',data=df,hue='fbs')
plt.title("visualize the frequency of target variable with fbs")
plt.show()

# %%
ax = plt.subplots(figsize=(8,6))
sns.countplot(x='target',data=df,hue='exang')
plt.title("visualize the frequency of target variable with exang")  
plt.show()

# %%
df.groupby('thalach')['target'].value_counts()
# Out:
# thalach  target
# 71       0         1
# 88       0         1
# 90       0         1
# 95       0         1
# 96       0         1
#                   ..
# 190      1         1
# 192      1         1
# 194      1         1
# 195      0         1
# 202      1         1
# Name: count, Length: 138, dtype: int64

# %%
# plotiing the maximum heart rate achieved 
ax = plt.subplots(figsize=(8,6))
sns.swarmplot(x='thalach',data=df,hue='target')
plt.title("visualize the frequency of target variable with thalach")
# Out:
# Text(0.5, 1.0, 'visualize the frequency of target variable with thalach')

# %%
plt.subplots(figsize=(8,6))
x = df['thalach']
sns.distplot(x,bins=20,color='green')
plt.grid(True)

# %%
plt.subplots(figsize=(8,6))
y = df['thalach']
sns.distplot(y,bins=20,color='green',vertical=True)
plt.grid(True)

# %% [markdown]
# #### Seaborn Kernel Density Estimation (KDE) Plot
#
#
# - The kernel density estimate (KDE) plot is a useful tool for plotting the shape of a distribution.
#
# - The KDE plot plots the density of observations on one axis with height along the other axis.
#
# - We can plot a KDE plot as follows :

# %%
plt.subplots(figsize=(8,6))
y = df['thalach']
y = pd.Series(y,name = 'talach')
sns.kdeplot(y)
plt.show()

# %% [markdown]
# # from above Kde plot we can fill the inside area with colors

# %%
plt.subplots(figsize=(8,6))
y = df['thalach']
y = pd.Series(y,name = 'talach')
sns.kdeplot(y,shade=True,color='green')
plt.show()

# %%
plt.subplots(figsize=(8,6))
y = df['thalach']
y = pd.Series(y,name = 'talach')
sns.kdeplot(y,shade=True,color= 'pink')
plt.show()

# %% [markdown]
# #### Histogram
#
# - A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# - We can plot a histogram as follows :

# %%
plt.subplots(figsize=(8,6))
sns.distplot(x,kde=True,rug=True)     # kde means gives the outerline and rug means gives the inner line
plt.show()

# %%
# visual frequency with Thalach and Target
ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x='thalach',y='target',data=df,hue='target')
# Out:
# <Axes: xlabel='thalach', ylabel='target'>

# %%
plt.subplots(figsize=(8,6))
sns.stripplot(x='target',y='thalach',data=df,hue='target')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
plt.subplots(figsize=(8,6))
sns.boxplot(x='target',y='thalach',data=df,hue='target')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
plt.subplots(figsize=(8,6))
sns.violinplot(x='target',y='thalach',data=df,hue='target')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(df[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %% [markdown]
# ### Estimate correlation coefficients <a class="anchor" id="8.1"></a>
#
# Our dataset is very small. So, I will compute the standard correlation coefficient (also called Pearson's r) between every pair of attributes. I will compute it using the `df.corr()` method as follows:-

# %%
correlation = df.corr()
correlation['target'].sort_values(ascending=False)
# it gives the correlation with all other variables(independent variables) with target variable(depending variable)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
plt.figure(figsize=(16,12))
a =sns.heatmap(correlation,square=True, annot = True ,fmt = '.2f')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=40)
# Out:
# [Text(0, 0.5, 'age'),
#  Text(0, 1.5, 'sex'),
#  Text(0, 2.5, 'cp'),
#  Text(0, 3.5, 'trestbps'),
#  Text(0, 4.5, 'chol'),
#  Text(0, 5.5, 'fbs'),
#  Text(0, 6.5, 'restecg'),
#  Text(0, 7.5, 'thalach'),
#  Text(0, 8.5, 'exang'),
#  Text(0, 9.5, 'oldpeak'),
#  Text(0, 10.5, 'slope'),
#  Text(0, 11.5, 'ca'),
#  Text(0, 12.5, 'thal'),
#  Text(0, 13.5, 'target')]

# %% [markdown]
# #### Interpretation
#
# From the above correlation heat map, we can conclude that :-
#
# - `target` and `cp` variable are mildly positively correlated (correlation coefficient = 0.43).
#
# - `target` and `thalach` variable are also mildly positively correlated (correlation coefficient = 0.42).
#
# - `target` and `slope` variable are weakly positively correlated (correlation coefficient = 0.35).
#
# - `target` and `exang` variable are mildly negatively correlated (correlation coefficient = -0.44).
#
# - `target` and `oldpeak` variable are also mildly negatively correlated (correlation coefficient = -0.43).
#
# - `target` and `ca` variable are weakly negatively correlated (correlation coefficient = -0.39).
#
# - `target` and `thal` variable are also waekly negatively correlated (correlation coefficient = -0.34).

# %% [markdown]
# Outlier Detection

# %% [markdown]
#  make boxplots to visualise outliers in the continuous numerical variables : -
#
# `age`, `trestbps`, `chol`, `thalach` and  `oldpeak` variables.

# %%
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# 1.age Boxenplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='age',data = df)
plt.show()

# %%
df['trestbps']
# Out:
# 0      145
# 1      130
# 2      130
# 3      120
# 4      120
#       ...
# 298    140
# 299    110
# 300    144
# 301    130
# 302    130
# Name: trestbps, Length: 303, dtype: int64

# %% [markdown]
# 2.Trestbps boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='trestbps',data = df)
plt.show()

# %%
df['chol']
# Out:
# 0      233
# 1      250
# 2      204
# 3      236
# 4      354
#       ...
# 298    241
# 299    264
# 300    193
# 301    131
# 302    236
# Name: chol, Length: 303, dtype: int64

# %% [markdown]
# 3.chol boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='chol',data = df)
plt.show()

# %%
df['thalach']
# Out:
# 0      150
# 1      187
# 2      172
# 3      178
# 4      163
#       ...
# 298    123
# 299    132
# 300    141
# 301    115
# 302    174
# Name: thalach, Length: 303, dtype: int64

# %% [markdown]
# 4.thalach Boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='thalach',data = df)
plt.show()

# %%
df['oldpeak']
# Out:
# 0      2.3
# 1      3.5
# 2      1.4
# 3      0.8
# 4      0.6
#       ...
# 298    0.2
# 299    1.2
# 300    3.4
# 301    1.2
# 302    0.0
# Name: oldpeak, Length: 303, dtype: float64

# %% [markdown]
# 5.Oldpeak Boxplot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='oldpeak',data = df)
plt.show()

# %% [markdown]
# #### Findings
#
# - The `age` variable does not contain any outlier.
#
# - `trestbps` variable contains outliers to the right side.
#
# - `chol` variable also contains outliers to the right side.
#
# - `thalach` variable contains a single outlier to the left side.
#
# - `oldpeak` variable contains outliers to the right side.
#
# - Those variables containing outliers needs further investigation.
